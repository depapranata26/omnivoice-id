# %% [markdown]
# <a href="https://colab.research.google.com/github/depapranata26/omnivoice-id/blob/master/OmniVoice-ID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

REPO = "/content/omnivoice-id"

if not os.path.exists(REPO):
    # !git clone https://github.com/depapranata26/omnivoice-id.git $REPO
else:
    # %cd $REPO
    # !git pull

# %cd $REPO

# %%
import torch

print("="*60)

print("OmniVoice-ID")

print("="*60)

print("Torch :", torch.__version__)

print("CUDA  :", torch.cuda.is_available())

if torch.cuda.is_available():

    print("GPU :", torch.cuda.get_device_name(0))

    print("VRAM :", round(torch.cuda.get_device_properties(0).total_memory/1024**3,2),"GB")

else:

    raise RuntimeError("GPU belum aktif")

# %%
import subprocess

try:
    import omnivoice
    print("OmniVoice sudah terinstall")
except ImportError:
    subprocess.run(["pip","install","-e","."])

# %%
import os

os.environ["HF_HOME"]="/content/drive/MyDrive/huggingface"

# %%
import datetime

print("Started :",datetime.datetime.now())

# %%
# !python -m omnivoice.cli.demo --share
