# %% [markdown]
# <a href="https://colab.research.google.com/github/depapranata26/omnivoice-id/blob/master/OmniVoice-ID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# OmniVoice-ID

## Google Colab Launcher

Repository:
https://github.com/depapranata26/omnivoice-id

Cara menggunakan

1. Runtime
2. Run all
3. Tunggu download model
4. Buka URL Gradio

# %%
import torch

print("="*40)
print("OmniVoice-ID")
print("="*40)

print("Torch :", torch.__version__)
print("CUDA  :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU   :", torch.cuda.get_device_name(0))
else:
    raise RuntimeError("GPU tidak aktif. Aktifkan GPU terlebih dahulu.")

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
import os

os.chdir("/content")

if not os.path.exists("omnivoice-id"):
    # !git clone https://github.com/depapranata26/omnivoice-id.git

# %cd /content/omnivoice-id

# %%
# !pip install -e .

# %%
# !python -m omnivoice.cli.demo --share
